# %% [markdown]
# # Example 7.1

# %%
# Opening a file
file = open("CHAPTER7_DATA.txt", "r")  # Read mode
file.close()

# %%
with open("CHAPTER7_DATA.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# YearsExperience	Salary
# 1.2	39344
# 1.4	46206
# 1.6	37732
# 2.1	43526
# 2.3	39892
# 3	56643
# 3.1	60151
# 3.3	54446
# 3.3	64446
# 3.8	57190
# 4	63219
# 4.1	55795
# 4.1	56958
# 4.2	57082
# 4.6	61112
# 5	67939
# 5.2	66030
# 5.4	83089
# 6	81364
# 6.1	93941
# 6.9	91739
# 7.2	98274
# 8	101303
# 8.3	113813
# 8.8	109432
# 9.1	105583
# 9.6	116970
# 9.7	112636
# 10.4	122392
# 10.6	121873

# %% [markdown]
# # Example 7.2

# %%
# Read entire file
with open("CHAPTER7_DATA.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# YearsExperience	Salary
# 1.2	39344
# 1.4	46206
# 1.6	37732
# 2.1	43526
# 2.3	39892
# 3	56643
# 3.1	60151
# 3.3	54446
# 3.3	64446
# 3.8	57190
# 4	63219
# 4.1	55795
# 4.1	56958
# 4.2	57082
# 4.6	61112
# 5	67939
# 5.2	66030
# 5.4	83089
# 6	81364
# 6.1	93941
# 6.9	91739
# 7.2	98274
# 8	101303
# 8.3	113813
# 8.8	109432
# 9.1	105583
# 9.6	116970
# 9.7	112636
# 10.4	122392
# 10.6	121873

# %% [markdown]
# # Example 7.3

# %%
with open("CHAPTER7_DATA.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# YearsExperience	Salary
# 1.2	39344
# 1.4	46206
# 1.6	37732
# 2.1	43526
# 2.3	39892
# 3	56643
# 3.1	60151
# 3.3	54446
# 3.3	64446
# 3.8	57190
# 4	63219
# 4.1	55795
# 4.1	56958
# 4.2	57082
# 4.6	61112
# 5	67939
# 5.2	66030
# 5.4	83089
# 6	81364
# 6.1	93941
# 6.9	91739
# 7.2	98274
# 8	101303
# 8.3	113813
# 8.8	109432
# 9.1	105583
# 9.6	116970
# 9.7	112636
# 10.4	122392
# 10.6	121873

# %% [markdown]
# # Example 7.4

# %%
with open("CHAPTER7_DATA.txt", "r") as file:
    print(file.read(10))  # Read first 10 characters
# Out:
# YearsExper

# %% [markdown]
# # Example 7.5

# %%
with open("CHAPTER7_DATA.txt", "r") as file:
    lines = file.readlines()
    print(lines)
# Out:
# ['YearsExperience\tSalary\n', '1.2\t39344\n', '1.4\t46206\n', '1.6\t37732\n', '2.1\t43526\n', '2.3\t39892\n', '3\t56643\n', '3.1\t60151\n', '3.3\t54446\n', '3.3\t64446\n', '3.8\t57190\n', '4\t63219\n', '4.1\t55795\n', '4.1\t56958\n', '4.2\t57082\n', '4.6\t61112\n', '5\t67939\n', '5.2\t66030\n', '5.4\t83089\n', '6\t81364\n', '6.1\t93941\n', '6.9\t91739\n', '7.2\t98274\n', '8\t101303\n', '8.3\t113813\n', '8.8\t109432\n', '9.1\t105583\n', '9.6\t116970\n', '9.7\t112636\n', '10.4\t122392\n', '10.6\t121873\n']

# %% [markdown]
# # Example 7.6

# %%
# Writing to a file
with open("CHAPTER7_DATA.txt", "w") as file:
    file.write("Hello, this is a sample text file.")

# %% [markdown]
# # Example 7.7

# %%
# Appending to a file
with open("CHAPTER7_DATA.txt", "a") as file:
    file.write("\nAppending new content.")

# %% [markdown]
# # Example 7.8

# %%
lines = ["First line\n", "Second line\n", "Third line\n"]
with open("CHAPTER7_DATA.txt", "w") as file:
    file.writelines(lines)

# %% [markdown]
# # Example 7.9

# %%
import csv

with open("CHAPTER7_DATA.csv", "r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['YearsExperience', 'Salary']
# ['1.2', '39344']
# ['1.4', '46206']
# ['1.6', '37732']
# ['2.1', '43526']
# ['2.3', '39892']
# ['3', '56643']
# ['3.1', '60151']
# ['3.3', '54446']
# ['3.3', '64446']
# ['3.8', '57190']
# ['4', '63219']
# ['4.1', '55795']
# ['4.1', '56958']
# ['4.2', '57082']
# ['4.6', '61112']
# ['5', '67939']
# ['5.2', '66030']
# ['5.4', '83089']
# ['6', '81364']
# ['6.1', '93941']
# ['6.9', '91739']
# ['7.2', '98274']
# ['8', '101303']
# ['8.3', '113813']
# ['8.8', '109432']
# ['9.1', '105583']
# ['9.6', '116970']
# ['9.7', '112636']
# ['10.4', '122392']
# ['10.6', '121873']

# %% [markdown]
# # Example 7.10

# %%
with open("CHAPTER7_DATA.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        print(row["YearsExperience"], row["Salary"])
# Out:
# 1.2 39344
# 1.4 46206
# 1.6 37732
# 2.1 43526
# 2.3 39892
# 3 56643
# 3.1 60151
# 3.3 54446
# 3.3 64446
# 3.8 57190
# 4 63219
# 4.1 55795
# 4.1 56958
# 4.2 57082
# 4.6 61112
# 5 67939
# 5.2 66030
# 5.4 83089
# 6 81364
# 6.1 93941
# 6.9 91739
# 7.2 98274
# 8 101303
# 8.3 113813
# 8.8 109432
# 9.1 105583
# 9.6 116970
# 9.7 112636
# 10.4 122392
# 10.6 121873

# %% [markdown]
# # Example 7.11

# %%
with open("CHAPTER7_DATA.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["YearsExperience", "Salary"])
    writer.writerow(["50", 2500000])

# %% [markdown]
# # Example 7.12

# %%
import csv
with open("CHAPTER7_DATA.csv", "w", newline="") as file:
    fieldnames = ["YearsExperience", "Salary"]
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerow({"YearsExperience": 51, "Salary": 2800000})

# %% [markdown]
# # Example 7.13

# %%
with open("CHAPTER7_DATA.csv", "a", newline="") as file:
    writer = csv.writer(file)
    writer.writerow([52, 3000000])

# %% [markdown]
# # Example 7.14

# %%
import json

with open("1mb.json", "r") as file:
    data = json.load(file)
    print(data)
# Out:
# [{'name': 'Ms. Autumn Skiles', 'email': 'katherine60@hotmail.com', 'address': '81323 Simone Flats Apt. 695\nSouth Lucileville, CO 24991', 'phone': '+1 (648) 391-8320', 'website': 'https://examplefile.com'}, {'name': 'Mrs. Reba Heathcote', 'email': 'kboyer@reichert.info', 'address': '13859 Pasquale Mountain Suite 734\nSouth Dayneview, WA 27288', 'phone': '619.230.2594', 'website': 'https://examplefile.com'}, {'name': 'Prof. Dale Schiller IV', 'email': 'dbrown@hotmail.com', 'address': '461 Hand Rapid\nLake Angeloville, KS 45943', 'phone': '(830) 797-0870 x597', 'website': 'https://examplefile.com'}, {'name': 'Miss Leonie Dach', 'email': 'joanie.toy@hackett.com', 'address': '2182 Brown Route Suite 918\nMariebury, ID 83868', 'phone': '(753) 618-9594 x983', 'website': 'https://examplefile.com'}, {'name': 'Ruth Stiedemann', 'email': 'wendy.zieme@yahoo.com', 'address': '762 Powlowski Prairie\nLake Hopestad, WV 47233-0316', 'phone': '(221) 299-7141 x80069', 'website': 'https://examplefile.co
# ...

# %% [markdown]
# # Example 7.15

# %%
data = {"Name": "Alice", "Age": 25, "City": "New York"}

with open("1mb.json", "w") as file:
    json.dump(data, file, indent=4)

# %% [markdown]
# # Example 7.16

# %%
json_string = '{"Name": "Alice", "Age": 25, "City": "New York"}'
data = json.loads(json_string)
print(data["Name"])  # Output: Alice
# Out:
# Alice

# %% [markdown]
# # Example 7.17

# %%
import xml.etree.ElementTree as ET

# Parsing XML data
tree = ET.parse('data.xml')
root = tree.getroot()

for child in root:
    print(child.tag, child.attrib)

# Creating XML data
root = ET.Element('root')
child = ET.SubElement(root, 'child')
child.set('name', 'Alice')
tree = ET.ElementTree(root)
tree.write('output.xml')

# %% [markdown]
# # Example 7.18

# %%
import yaml
# Reading YAML data
with open('data.yaml', 'r') as file:
    data = yaml.safe_load(file)
    print(data)
# Writing YAML data
data = {
    'Name': 'Alice',
    'Age': 30,
    'City': 'New York'
}
with open('output.yaml', 'w') as file:
    yaml.dump(data, file)

# %% [markdown]
# # Example 7.19

# %%
import pickle

# Serializing Python object
data = {
    'Name': 'Alice',
    'Age': 30,
    'City': 'New York'
}

with open('data.pkl', 'wb') as file:
    pickle.dump(data, file)

# Deserializing Python object
with open('data.pkl', 'rb') as file:
    data = pickle.load(file)
    print(data)

# %% [markdown]
# # Example 7.20

# %%
import json

# Reading configuration from a JSON file
with open('config.json', 'r') as file:
    config = json.load(file)
    print(config)
# Writing configuration to a JSON file
config = {
    'host': 'localhost',
    'port': 8080,
    'debug': True
}
with open('config.json', 'w') as file:
    json.dump(config, file, indent=4)

# %% [markdown]
# # Example 7.21

# %%
import csv

# Processing large CSV files in chunks
chunk_size = 1000
with open('large_data.csv', 'r') as file:
    reader = csv.reader(file)
    chunk = []
    for i, row in enumerate(reader):
        chunk.append(row)
        if i % chunk_size == 0 and i != 0:
            print(f'Processing chunk: {chunk}')
            chunk = []
    if chunk:
        print(f'Processing final chunk: {chunk}')

# %% [markdown]
# # Example 7.22

# %%
import json

# Handling nested JSON data
data = {
    'Name': 'Alice',
    'Age': 30,
    'Address': {
        'Street': '123 Main St',
        'City': 'New York',
        'State': 'NY'
    }
}
# Accessing nested data
print(data['Address']['City'])
# Modifying nested data
data['Address']['City'] = 'Los Angeles'
print(json.dumps(data, indent=4))

# %% [markdown]
# # Example 7.23

# %%
import pickle
# Serializing Python object
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

person = Person('Alice', 30)

with open('person.pkl', 'wb') as file:
    pickle.dump(person, file)

# Deserializing Python object
with open('person.pkl', 'rb') as file:
    loaded_person = pickle.load(file)
    print(loaded_person.name, loaded_person.age)

# %% [markdown]
# # Example 7.24

# %%
with open('CHAPTER7_DATA.txt', 'r') as file:
    for line in file:
        print(line, end='')
# Out:
# First line
# Second line
# Third line

# %% [markdown]
# # Example 7.25

# %%
# Open the file in write mode
fileID = open('CHAPTER7_DATA.txt', 'w')

# Write lines to the file
fileID.write('Line 1\n')
fileID.write('Line 2\n')

# Close the file
fileID.close()

# %% [markdown]
# # Example 7.26

# %%
with open('CHAPTER7_DATA.txt', 'a') as file:
    file.write('Line 3\n')

# %% [markdown]
# # Example 7.27

# %%
with open('fontawesome-webfont.bin', 'rb') as file:
    data = file.read()
    print(data)
# Out:
# b'\x00\x07FontAwe\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00LWFNGWp1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\xd9\xc5]\xeb\n\x86]\xeb\n\x86\x00\x00\x00mBIN\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x82\x81\x17Z\x
# ...

# %% [markdown]
# # Example 7.28

# %%
with open('fontawesome-webfont.bin', 'wb') as file:
    file.write(bytes([1, 2, 3, 4]))

# %% [markdown]
# # Example 7.29

# %%
import pandas as pd
data = pd.read_csv('CHAPTER7_DATA.csv')
print(data)
# Out:
#    YearsExperience   Salary
# 0               51  2800000
# 1               52  3000000

# %% [markdown]
# # Example 7.30

# %%
import pandas as pd
data = pd.DataFrame({'ID': [1, 2, 3], 'Letter': ['A', 'B', 'C']})
data.to_csv('CHAPTER7_DATA.csv', index=False)

# %% [markdown]
# # Example 7.31

# %%
import json
with open('1mb.json', 'r') as file:
    data = json.load(file)
    print(data)
# Out:
# {'Name': 'Alice', 'Age': 25, 'City': 'New York'}

# %% [markdown]
# # Example 7.32

# %%
import json
data = {'Name': 'Alice', 'Age': 30}
with open('1mb.json', 'w') as file:
    json.dump(data, file, indent=4)

# %% [markdown]
# # Example 7.33

# %%
import pandas as pd
data = pd.read_excel('CHAPTER7_DATA.xlsx')
print(data)
# Out:
#     YearsExperience  Salary
# 0               1.2   39344
# 1               1.4   46206
# 2               1.6   37732
# 3               2.1   43526
# 4               2.3   39892
# 5               3.0   56643
# 6               3.1   60151
# 7               3.3   54446
# 8               3.3   64446
# 9               3.8   57190
# 10              4.0   63219
# 11              4.1   55795
# 12              4.1   56958
# 13              4.2   57082
# 14              4.6   61112
# 15              5.0   67939
# 16              5.2   66030
# 17              5.4   83089
# 18              6.0   81364
# 19              6.1   93941
# 20              6.9   91739
# 21              7.2   98274
# 22              8.0  101303
# 23              8.3  113813
# 24              8.8  109432
# 25              9.1  105583
# 26              9.6  116970
# 27              9.7  112636
# 28             10.4  122392
# 29             10.6  121873

# %% [markdown]
# # Example 7.34

# %%
import pandas as pd
data = pd.DataFrame({'ID': [1, 2, 3], 'Letter': ['A', 'B', 'C']})
data.to_excel('CHAPTER7_DATA.xlsx', index=False)

# %% [markdown]
# # Example 7.35

# %%
import pandas as pd
data = pd.read_excel('CHAPTER7_DATA.xlsx', sheet_name='Sheet1')
print(data)
# Out:
#    ID Letter
# 0   1      A
# 1   2      B
# 2   3      C

# %% [markdown]
# # Example 7.36

# %%
import pandas as pd
data = pd.DataFrame({'ID': [1, 2, 3], 'Letter': ['A', 'B', 'C']})
with pd.ExcelWriter('CHAPTER7_DATA.xlsx') as writer:
    data.to_excel(writer, sheet_name='Sheet1', index=False)

# %% [markdown]
# # Example 7.37

# %%
import pandas as pd
data = pd.read_csv('CHAPTER7_DATA.csv', delimiter=';')
print(data)
# Out:
#   ID,Letter
# 0       1,A
# 1       2,B
# 2       3,C

# %% [markdown]
# # Example 7.38

# %%
import pandas as pd
data = pd.DataFrame({'ID': [1, 2, 3], 'Letter': ['A', 'B', 'C']})
data.to_csv('CHAPTER7_DATA.csv', sep=';', index=False)

# %% [markdown]
# # Example 7.39

# %%
import pandas as pd
data = pd.read_csv('CHAPTER7_DATA.csv', na_values=['NA'])
print(data)
# Out:
#   ID;Letter
# 0       1;A
# 1       2;B
# 2       3;C

# %% [markdown]
# # Example 7.40

# %%
import pandas as pd
import numpy as np
data = pd.DataFrame({'ID': [1, np.nan, 3], 'Letter': ['A', 'B', 'C']})
data.to_csv('output.csv', index=False)

# %% [markdown]
# # Example 7.41

# %%
import json
with open('data.json', 'r') as file:
    data = json.load(file)
    print(data['Address']['City'])

# %% [markdown]
# # Example 7.42

# %%
import json
data = {'Name': 'Alice', 'Age': 30, 'Address': {'City': 'New York'}}
with open('output.json', 'w') as file:
    json.dump(data, file, indent=4)

# %% [markdown]
# # Example 7.43

# %%
import pandas as pd
data = pd.read_csv('data.csv', skiprows=1)
print(data)

# %% [markdown]
# # Example 7.44

# %%
import pandas as pd
data = pd.DataFrame({'ID': [1, 2, 3], 'Letter': ['A', 'B', 'C']})
data.to_csv('output.csv', index=False, header=False)

# %% [markdown]
# # Example 7.45

# %%
import pandas as pd
data = pd.read_csv('data.csv', usecols=['ID', 'Letter'])
print(data)

# %% [markdown]
# # Example 7.46

# %%
import pandas as pd
data = pd.DataFrame({'ID': [1, 2, 3], 'Letter': ['A', 'B', 'C']})
data.to_csv('output.csv', columns=['ID', 'Letter'], index=False)

# %% [markdown]
# # Example 7.47

# %%
import pandas as pd
data = pd.read_csv('data.csv', encoding='utf-8')
print(data)

# %% [markdown]
# # Example 7.48

# %%
import pandas as pd
data = pd.DataFrame({'ID': [1, 2, 3], 'Letter': ['A', 'B', 'C']})
data.to_csv('output.csv', encoding='utf-8', index=False)

# %% [markdown]
# # Example 7.49

# %%
import pandas as pd
data = pd.read_csv('data.csv', parse_dates=['Date'])
print(data)

# %% [markdown]
# # Example 7.50

# %%
import pandas as pd
from datetime import datetime
data = pd.DataFrame({'Date': [datetime.now()], 'ID': [1, 2, 3], 'Letter': ['A', 'B', 'C']})
data.to_csv('output.csv', index=False)

# %% [markdown]
# # Example 7.51

# %%
import pandas as pd
data = pd.read_csv('data.csv', parse_dates=['Date'], date_format='%d/%m/%Y')
print(data)

# %% [markdown]
# # Example 7.52

# %%
import pandas as pd
from datetime import datetime
data = pd.DataFrame({'Date': [datetime.now()], 'ID': [1, 2, 3], 'Letter': ['A', 'B', 'C']})
data.to_csv('output.csv', index=False, date_format='%d/%m/%Y')

# %% [markdown]
# # Example 7.53

# %%
import pandas as pd
data = pd.read_csv('data.csv', na_values=['NA', 'NaN'])
print(data)

# %% [markdown]
# # Example 7.54

# %%
import pandas as pd
import numpy as np
data = pd.DataFrame({'ID': [1, np.nan, 3], 'Letter': ['A', 'B', 'C']})
data.to_csv('output.csv', index=False, na_rep='NA')

# %% [markdown]
# # Example 7.55

# %%
import pandas as pd
data = pd.read_csv('data.csv', quotechar='"')
print(data)

# %% [markdown]
# # Example 7.56

# %%
import pandas as pd
data = pd.DataFrame({'ID': [1, 2, 3], 'Letter': ['A', 'B', 'C']})
data.to_csv('output.csv', index=False, quotechar='"')

# %% [markdown]
# # Example 7.57

# %%
import pandas as pd
data = pd.read_csv('data.csv', comment='#')
print(data)

# %% [markdown]
# # Example 7.58

# %%
import pandas as pd

# Create the DataFrame
data = pd.DataFrame({'ID': [1, 2, 3], 'Letter': ['A', 'B', 'C']})

# Define the comment(s) you want to add
comments = [
    "# This is a comment line 1",
    "# This is a comment line 2"
]

# Write the comments and DataFrame to the CSV file
with open('output.csv', 'w') as file:
    # Write the comments
    for comment in comments:
        file.write(comment + '\n')
    # Write the DataFrame to the file
    data.to_csv(file, index=False)

# %% [markdown]
# # Example 7.59

# %%
import pandas as pd
data = pd.read_csv('CHAPTER7_DATA.csv', thousands=',')
print(data)
# Out:
#    YearsExperience  Salary
# 0               10   10000
# 1               20   20000
# 2               30   30000

# %% [markdown]
# # Example 7.60

# %%
import pandas as pd

# Create the DataFrame
data = pd.DataFrame({'YearsExperience': [10, 20, 30], 'Salary': [10000, 20000, 30000]})

# Format the 'Salary' column with a thousands separator
data['Salary'] = data['Salary'].apply(lambda x: f"{x:,}")

# Write the DataFrame to a CSV file
data.to_csv('CHAPTER7_DATA.csv', index=False)
