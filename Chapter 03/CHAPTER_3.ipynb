# %%
a = 5 + 3
print(a)
# Out:
# 8

# %%
b = 10 - 2
print(b)
# Out:
# 8

# %%
c = 4 * 3
print(c)
# Out:
# 12

# %%
d = 10 / 3
print(d)
# Out:
# 3.3333333333333335

# %%
e = 10 // 3
print(e)
# Out:
# 3

# %%
f = 2 ** 3
print(f)
# Out:
# 8

# %%
first_name = "John"
last_name = "Doe"
full_name = first_name + " " + last_name
print(full_name)
# Out:
# John Doe

# %%
text = "Hello, World!"
substring = text[7:12]   # Extracts characters from index 7 up to, but not including, index 12
print(substring)
# Out:
# World

# %%
name = "Alice"
age = 30
message = f"Hello, {name}! You are {age} years old."
print(message)
# Out:
# Hello, Alice! You are 30 years old.

# %%
name = "Alice"
age = 30
message = "Hello, {}! You are {} years old.".format(name, age)
print(message)
# Out:
# Hello, Alice! You are 30 years old.

# %%
name = "Alice"
age = 30
message = "Hello, %s! You are %d years old." % (name, age)
print(message)
# Out:
# Hello, Alice! You are 30 years old.

# %%
text = "hello"
uppercase_text = text.upper()
print(uppercase_text)
# Out:
# HELLO

# %%
text = "HELLO"
lowercase_text = text.lower()
print(lowercase_text)
# Out:
# hello

# %%
text = "Hello, World!"
new_text = text.replace("World", "Python")
print(new_text)
# Out:
# Hello, Python!

# %%
text = "Hello, World!"
position = text.find("World")
print(position)
# Out:
# 7

# %%
text = "apple,banana,cherry"
fruits = text.split(",")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
empty_list = []
print(empty_list)
# Out:
# []

# %%
numbers = [1, 2, 3, 4, 5]
print(numbers)  # Output: [1, 2, 3, 4, 5]

fruits = ["apple", "banana", "cherry"]
print(fruits)
# Out:
# [1, 2, 3, 4, 5]
# ['apple', 'banana', 'cherry']

# %%
mixed_list = [1, "hello", 3.14, True]
print(mixed_list)
# Out:
# [1, 'hello', 3.14, True]

# %%
range_list = list(range(1, 6))  # Creates a list of numbers from 1 to 5
print(range_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
squares = [x**2 for x in range(1, 6)]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
print(matrix)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
text = "hello"
char_list = list(text)
print(char_list)
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
tuple_data = (1, 2, 3)
list_data = list(tuple_data)
print(list_data)
# Out:
# [1, 2, 3]

# %%
duplicates = ["apple"] * 3
print(duplicates)
# Out:
# ['apple', 'apple', 'apple']

# %%
dynamic_list = []
dynamic_list.append(1)
dynamic_list.append(2)
dynamic_list.append(3)
print(dynamic_list)
# Out:
# [1, 2, 3]

# %%
my_list = [10, 20, 30, 40, 50]
first_element = my_list[0]
print(first_element)
# Out:
# 10

# %%
last_element = my_list[-1]
print(last_element)
# Out:
# 50

# %%
my_list = [10, 20, 30, 40, 50]
subset = my_list[1:4]
print(subset)
# Out:
# [20, 30, 40]

# %%
start_from_beginning = my_list[:3]
print(start_from_beginning)
# Out:
# [10, 20, 30]

# %%
end_to_last = my_list[2:]
print(end_to_last)
# Out:
# [30, 40, 50]

# %%
last_two_elements = my_list[-2:]
print(last_two_elements)
# Out:
# [40, 50]

# %%
my_list = [10, 20, 30, 40, 50]
every_other = my_list[::2]
print(every_other)
# Out:
# [10, 30, 50]

# %%
reversed_list = my_list[::-1]
print(reversed_list)
# Out:
# [50, 40, 30, 20, 10]

# %%
text = "Python"
# Accessing a single character
first_char = text[0]
print(first_char)
# Out:
# P

# %%
text = "Python"
# Slicing a substring
substring = text[1:4]
print(substring)
# Out:
# yth

# %%
text = "Python"
# Reversing the string
reversed_text = text[::-1]
print(reversed_text)
# Out:
# nohtyP

# %%
matrix = [[1, 2, 3],
[4, 5, 6],
[7, 8, 9]]
element = matrix[1][2]  
print(element)
# Out:
# 6

# %%
my_list = [1, 2, 3]
my_list.append(4)
print(my_list)
# Out:
# [1, 2, 3, 4]

# %%
words = ["hello", "world"]
words.append("Python")
print(words)
# Out:
# ['hello', 'world', 'Python']

# %%
my_list = [1, 2, 3]
my_list.extend([4, 5, 6])
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
fruits = ["apple", "banana"]
fruits.extend(("cherry", "date"))  # You can extend with a tuple
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'date']

# %%
my_list = [1, 2, 3]
my_list.append([4, 5])
print(my_list)
# Out:
# [1, 2, 3, [4, 5]]

# %%
my_list = [1, 2, 3]
my_list.extend([4, 5])
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
my_list = [10, 20, 30, 20, 40]
my_list.remove(20)  # Removes the first occurrence of 20
print(my_list)
# Out:
# [10, 30, 20, 40]

# %%
my_list = [10, 20, 30, 40, 50]
last_element = my_list.pop()  # Removes the last element
print(last_element)  
print(my_list)
# Out:
# 50
# [10, 20, 30, 40]

# %%
specific_element = my_list.pop(1)  # Removes element at index 1
print(specific_element)  
print(my_list)
# Out:
# 20
# [10, 30, 40]

# %%
my_list = [10, 20, 30, 40, 50]
del my_list[1]  # Deletes element at index 1
print(my_list)
# Out:
# [10, 30, 40, 50]

# %%
# Deleting a slice of elements
del my_list[1:3]  # Deletes elements from index 1 up to, but not including, index 3
print(my_list)
# Out:
# [10, 50]

# %%
my_list = [5, 2, 9, 1, 7]
my_list.sort()  # Sorts in ascending order
print(my_list)
# Out:
# [1, 2, 5, 7, 9]

# %%
my_list.sort(reverse=True)  # Sorts in descending order
print(my_list)
# Out:
# [9, 7, 5, 2, 1]

# %%
my_list = [5, 2, 9, 1, 7]
sorted_list = sorted(my_list)  # Sorts in ascending order
print(sorted_list)  
print(my_list)
# Out:
# [1, 2, 5, 7, 9]
# [5, 2, 9, 1, 7]

# %%
my_list = [5, 2, 9, 1, 7]
# Sorting in descending order
sorted_descending = sorted(my_list, reverse=True)
print(sorted_descending)
# Out:
# [9, 7, 5, 2, 1]

# %%
my_list = [5, 2, 9, 1, 7]
my_list.reverse()  # Reverses the order of elements
print(my_list)
# Out:
# [7, 1, 9, 2, 5]

# %%
my_list = [1, 2, 3, 4, 5]
list_length = len(my_list)
print(list_length)
# Out:
# 5

# %%
my_string = "Hello, world!"
string_length = len(my_string)
print(string_length)
# Out:
# 13

# %%
number = 42
print(type(number))  

text = "Python"
print(type(text))  

items = [1, 2, 3]
print(type(items))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'list'>

# %%
name = "Alice"
age = 30
print("Name:", name, "Age:", age)
# Out:
# Name: Alice Age: 30

# %%
name = "Alice"
age = 30
# Using formatted strings (f-strings)
print(f"{name} is {age} years old.")
# Out:
# Alice is 30 years old.

# %%
numbers = [10, 20, 30, 40]
total = sum(numbers)
print(total)
# Out:
# 100

# %%
numbers = [10, 20, 30, 40]
# Sum with a starting value
total_with_start = sum(numbers, 10)
print(total_with_start)
# Out:
# 110

# %% [markdown]
# # Example 3.1

# %%
# Define variables
a = 12
b = 5

# Arithmetic operations
addition = a + b
subtraction = a - b
multiplication = a * b
division = a / b
exponentiation = a ** b
modulus = a % b

# Display results
print("Addition:", addition)
print("Subtraction:", subtraction)
print("Multiplication:", multiplication)
print("Division:", division)
print("Exponentiation:", exponentiation)
print("Modulus:", modulus)
# Out:
# Addition: 17
# Subtraction: 7
# Multiplication: 60
# Division: 2.4
# Exponentiation: 248832
# Modulus: 2

# %% [markdown]
# # Example 3.2

# %%
import numpy as np

# Define matrices
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

# Matrix operations
matrix_addition = A + B
matrix_subtraction = A - B
elementwise_multiplication = A * B
matrix_multiplication = A @ B

# Display results
print("Matrix Addition:\n", matrix_addition)
print("Matrix Subtraction:\n", matrix_subtraction)
print("Element-wise Multiplication:\n", elementwise_multiplication)
print("Matrix Multiplication:\n", matrix_multiplication)
# Out:
# Matrix Addition:
#  [[ 6  8]
#  [10 12]]
# Matrix Subtraction:
#  [[-4 -4]
#  [-4 -4]]
# Element-wise Multiplication:
#  [[ 5 12]
#  [21 32]]
# Matrix Multiplication:
#  [[19 22]
#  [43 50]]

# %% [markdown]
# # Example 3.3

# %%
# Define variables
a = 7
b = 3

# Logical operations
is_equal = (a == b)
is_not_equal = (a != b)
is_greater_than = (a > b)
is_less_than_or_equal = (a <= b)

# Display results
print("Is Equal:", is_equal)
print("Is Not Equal:", is_not_equal)
print("Is Greater Than:", is_greater_than)
print("Is Less Than or Equal:", is_less_than_or_equal)
# Out:
# Is Equal: False
# Is Not Equal: True
# Is Greater Than: True
# Is Less Than or Equal: False
